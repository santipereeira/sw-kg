# %% [markdown]
# **Task 09: Data linking**

# %%
# !pip install rdflib
github_storage = "../rdf/"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rdflib in c:\users\yarac\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (7.5.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\yarac\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from rdflib) (3.2.1)
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\yarac\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from rdflib import Graph, Namespace, Literal, URIRef
g1 = Graph()
g2 = Graph()
g3 = Graph()
g1.parse(github_storage+"data03.rdf", format="xml")
g2.parse(github_storage+"data04.rdf", format="xml")
# Out:
# <Graph identifier=Nf0efac107f0d429baa11d2be57e5561f (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Busca individuos en los dos grafos y enlázalos mediante la propiedad OWL:sameAs, inserta estas coincidencias en g3. Consideramos dos individuos iguales si tienen el mismo apodo y nombre de familia. Ten en cuenta que las URI no tienen por qué ser iguales para un mismo individuo en los dos grafos.
